# %%
# !wget --header 'accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7' \
     --header 'accept-language: en-US,en;q=0.9,ru-RU;q=0.8,ru;q=0.7' \
     --header 'Cookie: i=JFIBS0OIhq0QnL/2e0i0M1F4r+sP66Nd+dKy1IkJ9y425Id8OHwGH4bi5lXH8JEhFiSP0olT48taPxjQAqSoKLPBZKw=; yandexuid=8133185461776868298; yuidss=8133185461776868298; ymex=1808404298.yrts.1776868298#1808404298.yrtsi.1776868298; _yasc=vYaDaReziQozJTaOuVenaLr5nrH/+7BqOrhHUvqlOxl4fw5xpVakIMfVU6vz/zc=; yashr=1320519201776868346; receive-cookie-deprecation=1; gdpr=0; _ym_uid=1776878879162630283; _ym_d=1776878881; bh=' \
     --header 'dnt: 1' \
     --header 'priority: u=0, i' \
     --header 'referer: https://disk.yandex.com/' \
     --header 'sec-ch-ua: "Not:A-Brand";v="99", "Google Chrome";v="145", "Chromium";v="145"' \
     --header 'sec-ch-ua-mobile: ?0' \
     --header 'sec-ch-ua-platform: "Linux"' \
     --header 'sec-fetch-dest: iframe' \
     --header 'sec-fetch-mode: navigate' \
     --header 'sec-fetch-site: same-site' \
     --header 'sec-fetch-user: ?1' \
     --header 'upgrade-insecure-requests: 1' \
     --user-agent 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36' \
     'https://downloader.disk.yandex.com/disk/1afc5a03b5d968ab8b5f8701e72328146ab5486da31f6b7a65b6a5d3a0b5158c/69e91586/zdBGJY6AJT-Uft4xEis0lvE1pGky5zR3gqDRLzpUbd4s-ulX3zth5pLjFBSj8OqFGzI32O1Yfdn6hqpiiMubNg%3D%3D?uid=0&filename=facades_dataset_v0.zip&disposition=attachment&hash=n/JEE1vi44rzzXRMyktDg/8bKALvjwwwqWQQ2I2O7pZci5DBs9JG3yIpLDG5CV2Vq/J6bpmRyOJonT3VoXnDag%3D%3D&limit=0&content_type=application%2Fzip&owner_uid=636971210&fsize=14012149697&hid=526388ab8107e901b53821c11d8f061e&media_type=compressed&tknv=v3'
# Out:
# --2026-04-22 20:38:12--  https://downloader.disk.yandex.com/disk/118a029fe40dbcc0975ee4f652093714f6f0f392b13240d1fd944cc08a0b152d/69e9699d/zdBGJY6AJT-Uft4xEis0lvE1pGky5zR3gqDRLzpUbd4s-ulX3zth5pLjFBSj8OqFGzI32O1Yfdn6hqpiiMubNg%3D%3D?uid=0&filename=facades_dataset_v0.zip&disposition=attachment&hash=n/JEE1vi44rzzXRMyktDg/8bKALvjwwwqWQQ2I2O7pZci5DBs9JG3yIpLDG5CV2Vq/J6bpmRyOJonT3VoXnDag%3D%3D&limit=0&content_type=application%2Fzip&owner_uid=636971210&fsize=14012149697&hid=526388ab8107e901b53821c11d8f061e&media_type=compressed&tknv=v3
# Resolving downloader.disk.yandex.com (downloader.disk.yandex.com)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.com (downloader.disk.yandex.com)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s102vla.storage.yandex.net/rdisk/118a029fe40dbcc0975ee4f652093714f6f0f392b13240d1fd944cc08a0b152d/69e9699d/zdBGJY6AJT-Uft4xEis0lvE1pGky5zR3gqDRLzpUbd4s-ulX3zth5pLjFBSj8OqFGzI32O1Yfdn6hqpiiMubNg==?uid=0&filename=facades_dataset_v0.zip&disposition=attachment&hash=n/JEE1vi44rzzXRMyktDg/8bKALvjwwwqWQQ2I2O7pZci5DBs9JG3yIpLDG5CV2Vq/J6bpmRyOJonT3VoXnDag%3D%3D&limit=0&content_type=application%2Fzip&owner_uid=636971210&fsize=14012149697&hid=526388ab8107e901b53821c11d8f061e&media_type=compressed&tknv=v3&ts=65015d7c7e140&s=695ee01b599eb81702425a14b11a7ff4e0ea714ddf7507a22dfaf03a54f83afa&pb=U2FsdGVkX1-1u210hIDzf1bGE9RAqJvjKULu3Nij36qC9mHQuXWxEe2fOOqbKrgDTLbOPm9dvid8oEBqfKUwgVIZFIqw6rDOjRAI4YiglmA [following]
# --2026-04-22 20:38:14--  https://s102vla.storage.yandex.net/rdisk/118a029fe40dbcc0975ee4f652093714f6f0f392b13240d1fd944cc08a0b152d/69e9699d/zdBGJY6AJT-Uft4xEis0lvE1pGky5zR3gqDRLzpUbd4s-ulX3zth5pLjFBSj8OqFGzI32O1Yfdn6hqpiiMubNg==?uid=0&filename=facades_dataset_v0.zip&disposition=attachment&hash=n/JEE1vi44rzzXRMyktDg/8bKALvjwwwqWQQ2I2O7pZci5DBs9JG3yIpLDG5CV2Vq/J6bpmRyOJonT3VoXnDag%3D%3D&limit=0&content_type=application%2Fzip&owner_uid=636971210&fsize=14012149697&hid=526388ab8107e901b53821c11d8f061e&media_type=compressed&tknv=v3&ts=65015d7c7e140&s=695ee01b599eb81702425a14b11a7ff4e0ea714ddf7507a22dfaf03a54f83afa&pb=U2FsdGVkX1-1u210hIDzf1bGE9RAqJvjKULu3Nij36qC9mHQuXWxEe2fOOqbKrgDTLbOPm9dvid8oEBqfKUwgVIZFIqw6rDOjRAI4YiglmA
# Resolving s102vla.storage.yandex.net (s102vla.storage.yandex.net)... 93.158.162.231, 2a02:6b8:c0e:181:0:41af:628d:c35
# Connecting to s102vla.storage.yandex.net (s102vla.storage.yandex.net)|93.158.162.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14012149697 (13G) [application/zip]
# Saving to: ‘facades_dataset_v0.zip’
#
# facades_dataset_v0. 100%[===================>]  13.05G  21.8MB/s    in 10m 19s
#
# 2026-04-22 20:48:34 (21.6 MB/s) - ‘facades_dataset_v0.zip’ saved [14012149697/14012149697]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/facades_dataset_v0.zip /content/drive/MyDrive/

# %%
# !cp /content/drive/MyDrive/facades_dataset_v0.zip /content/
# Out:
# cp: cannot stat '/content/drive/MyDrive/facades_dataset_v0.zip': No such file or directory

# %%
# !unzip facades_dataset_v0.zip
# Out:
# Archive:  facades_dataset_v0.zip
#  extracting: facades_dataset_v0/cefalet_1.png
#  extracting: facades_dataset_v0/cefalet_10.png
#  extracting: facades_dataset_v0/cefalet_11.png
#  extracting: facades_dataset_v0/cefalet_12.png
#  extracting: facades_dataset_v0/cefalet_17.png
#  extracting: facades_dataset_v0/cefalet_18.png
#  extracting: facades_dataset_v0/cefalet_19.png
#  extracting: facades_dataset_v0/cefalet_2.png
#  extracting: facades_dataset_v0/cefalet_20.png
#  extracting: facades_dataset_v0/cefalet_21.png
#  extracting: facades_dataset_v0/cefalet_22.png
#  extracting: facades_dataset_v0/cefalet_23.png
#  extracting: facades_dataset_v0/cefalet_24.png
#  extracting: facades_dataset_v0/cefalet_25.png
#  extracting: facades_dataset_v0/cefalet_26.png
#  extracting: facades_dataset_v0/cefalet_3.png
#  extracting: facades_dataset_v0/cefalet_31.png
#  extracting: facades_dataset_v0/cefalet_32.png
#  extracting: facades_dataset_v0/cefalet_33.png
#  extracting: facades_dataset_v0/cefalet_34.png
#  extracting: facades_dataset_v0/cefalet_35.png
#  extracting: facades_dataset_v0/cefalet_36.png
#  extracting: facades_dataset_v0/cefalet_37.png
#  extracting: facades_dataset_v0/cefalet_38.png
#  extracting: facades_dataset_v0/cefalet_39.png
#  extracting: facades_dataset_v0/cefalet_4.png
#  extracting: facades_dataset_v0/cefalet_40.png
#  extracting: facades_dataset_v0/cefalet_41.png
#  extracting: facades_dataset_v0/cefalet_42.png
#  extracting: facades_dataset_v0/cefalet_43.png
#  extracting: facades_dataset_v0/cefalet_44.png
#  extracting: facades_dataset_v0/cefalet_45.png
#  extracting: facades_dataset_v0/cefalet_46.png
#  extracting: facades_dataset_v0/cefalet_47.png
#  extracting: facades_dataset_v0/cefalet_48.png
#  extracting: facades_dataset_v0/cefalet_49.png
#  extracting: facades_dataset_v0/cefalet_5.png
#  extracting: facades_dataset_v0/cefalet_50.png
#  extracting: facades_dataset_v0/cefalet_51.png
#  extracting: facades_dataset_v0/cefalet_52.png
#  extracting: facades_dataset_v0/cefalet_53.png
#  extracting: facades_dataset_v0/cefalet_54.png
#  extracting: facades_dataset_v0/cefalet_55.png
#  extracting: facades_dataset_v0/cefalet_56.png
#  extracting: facades_dataset_v0/cefalet_57.png
#  extracting: facades_dataset_v0/cefalet_58.png
#  extracting: facades_dataset_v0/cefalet_59.png
#  extracting: facades_dataset_v0/cefalet_6.png
#  extracting: facades_dataset_v0/cefalet_60.png
#  extracting: facades_dataset_v0/cefalet_7.png
#  extracting: facades_dataset_v0/cefalet_8.png
#  extracting: facades_dataset_v0/cefalet_9.png
#  extracting: facades_dataset_v0/drozdov_2025_11_19_╨Э╨Т╨Х_╨и╨Ъ_╨░╨╗╤М╨▒╨╛╨╝_╨Ъ╨н╨б (1)-15_1.png
#  extracting: facades_dataset_v0/drozdov_2025_11_19_╨Э╨Т╨Х_╨и╨Ъ_╨░╨╗╤М╨▒╨╛╨╝_╨Ъ╨н╨б (1)-15_2.png
#  extracting: facades_dataset_v0/drozdov_241017_╨а╨╛╨╝╨░╨╜╨╛╨▓╤Б╨║╨╛╨╡ ╨Р╨У╨Ю+-39_31.png
#  extracting: facades_dataset_v0/drozdov_241017_╨а╨╛╨╝╨░╨╜╨╛╨▓╤Б╨║╨╛╨╡ ╨Р╨У╨Ю+-40_32.png
#  extracting: facades_dataset_v0/drozdov_241017_╨а╨╛╨╝╨░╨╜╨╛╨▓╤Б╨║╨╛╨╡ ╨Р╨У╨Ю+-40_33.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-13.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-19_2.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-22_6.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-23_7.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-27_14.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-28_15.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-30_18.png
#  extracting: facades_dataset_v0/drozdov_250606_╨п╨╜╨╕╨╜╨╛ ╨Ч╨г13_╨Р╨У╨Ю-31_19.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю ╨╛╨┤╨╛ 170-15_1.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю ╨╛╨┤╨╛ 170-16_2.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю ╨╛╨┤╨╛ 170-17_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю ╨╛╨┤╨╛ 170-18_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-47_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-48_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-49_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-50_7.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-51_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-52_7.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-53_7.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-55_9.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-57_10.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-58_2.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-59_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-27_1.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-28_2.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-29_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-30_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-31_5.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-32_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-34_7.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-35_8.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-36_9.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨г╤З╨░╤Б╤В╨╛╨║ 11_25.02.2025-37_10.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-37_1.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-37_2.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-38_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-38_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-39_5.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-39_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-40_7.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-41_8.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-42_11.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-43_12.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-43_13.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-44_13.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю_╨п╨╜╨╕╨╜╨╛_╨Р╤Н╤А╨╛╨┤╤А╨╛╨╝_18-44_14.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-20_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-21_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-22_5.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-23_6.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-27_8.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-28_9.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨У╨Ю╨Ю ╨Ь╤Г╤А╨╕╨╜╨╛ 1.14 ╨Р╨╗╤М╨▒╨╛╨╝-29_10.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-13_1.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-13_2.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-14_3.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-14_4.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-18_11.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-19.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-19_12.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-20_13.png
#  extracting: facades_dataset_v0/drozdov_╨Р╨╗╤М╨▒╨╛╨╝ ╨Р╨У╨Ю ╨в╨╛╤Б╨╜╨╛ ╨Ф╨╡╨╗╤М╤Д╨╕╨╜╨╡╨╜╨╛╨║-20_14.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ1 - ╨Ь╨Ъ╨Ф ╨│.╨Т╤Л╨▒╨╛╤А╨│-21_1.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ1 - ╨Ь╨Ъ╨Ф ╨│.╨Т╤Л╨▒╨╛╤А╨│-22_2.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ1 - ╨Ь╨Ъ╨Ф ╨│.╨Т╤Л╨▒╨╛╤А╨│-23_3.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ1 - ╨Ь╨Ъ╨Ф ╨│.╨Т╤Л╨▒╨╛╤А╨│-24_3.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ2 - ╨д╨░╨▒╤А╨╕╨║╨░ ╨Ь╨░╤В╤В╨╕-19_4.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ2 - ╨д╨░╨▒╤А╨╕╨║╨░ ╨Ь╨░╤В╤В╨╕-20_5.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ2 - ╨д╨░╨▒╤А╨╕╨║╨░ ╨Ь╨░╤В╤В╨╕-22_6.png
#  extracting: facades_dataset_v0/drozdov_╨Т╨╛╨┐╤А╨╛╤Б тДЦ2 - ╨д╨░╨▒╤А╨╕╨║╨░ ╨Ь╨░╤В╤В╨╕-22_8.png
#  extracting: facades_dataset_v0/drozdov_╨Ю╨▒╤Й╨╡╨╢╨╕╤В╨╕╨╡ ╨Ъ╨░╤Й╨╡╨╜╨║╨╛-23_2.png
#  extracting: facades_dataset_v0/drozdov_╨Ю╨▒╤Й╨╡╨╢╨╕╤В╨╕╨╡ ╨Ъ╨░╤Й╨╡╨╜╨║╨╛-24_3.png
#  extracting: facades_dataset_v0/drozdov_╨Ю╨▒╤Й╨╡╨╢╨╕╤В╨╕╨╡ ╨Ъ╨░╤Й╨╡╨╜╨║╨╛-25_4.png
#  extracting: facades_dataset_v0/drozdov_╨Ю╨▒╤Й╨╡╨╢╨╕╤В╨╕╨╡ ╨Ъ╨░╤Й╨╡╨╜╨║╨╛-26_1.png
#  extracting: facades_dataset_v0/drozdov_╤Б╤В╤А╨╛╨╕╤В╨╡╨╗╤М╨╜╤Л╨╕╠Ж ╤В╤А╨╡╤Б╤В_251125_CURV-13_3.png
#  extracting: facades_dataset_v0/drozdov_╤Б╤В╤А╨╛╨╕╤В╨╡╨╗╤М╨╜╤Л╨╕╠Ж ╤В╤А╨╡╤Б╤В_251125_CURV-3_1.png
#  extracting: facades_dataset_v0/drozdov_╤Б╤В╤А╨╛╨╕╤В╨╡╨╗╤М╨╜╤Л╨╕╠Ж ╤В╤А╨╡╤Б╤В_251125_CURV-8_2.png
#  extracting: facades_dataset_v0/drozdov_╨п╨╜╨╕╨╜╨╛_╨в╨Ю╨С╨Х_20808,10,05-33_16.png
#  extracting: facades_dataset_v0/ermoljev_1.png
#  extracting: facades_dataset_v0/ermoljev_10.png
#  extracting: facades_dataset_v0/ermoljev_100.png
#  extracting: facades_dataset_v0/ermoljev_101.png
#  extracting: facades_dataset_v0/ermoljev_102.png
#  extracting: facades_dataset_v0/ermoljev_103.png
#  extracting: facades_dataset_v0/ermoljev_104.png
#  extracting: facades_dataset_v0/ermoljev_105.png
#  extracting: facades_dataset_v0/ermoljev_106.png
#  extracting: facades_dataset_v0/ermoljev_107.png
#  extracting: facades_dataset_v0/ermoljev_108.png
#  extracting: facades_dataset_v0/ermoljev_109.png
#  extracting: facades_dataset_v0/ermoljev_11.png
#  extracting: facades_dataset_v0/ermoljev_110.png
#  extracting: facades_dataset_v0/ermoljev_111.png
#  extracting: facades_dataset_v0/ermoljev_112.png
#  extracting: facades_dataset_v0/ermoljev_113.png
#  extracting: facades_dataset_v0/ermoljev_114.png
#  extracting: facades_dataset_v0/ermoljev_115.png
#  extracting: facades_dataset_v0/ermoljev_116.png
#  extracting: facades_dataset_v0/ermoljev_117.png
#  extracting: facades_dataset_v0/ermoljev_118.png
#  extracting: facades_dataset_v0/ermoljev_119.png
#  extracting: facades_dataset_v0/ermoljev_12.png
#  extracting: facades_dataset_v0/ermoljev_120.png
#  extracting: facades_dataset_v0/ermoljev_121.png
#  extracting: facades_dataset_v0/ermoljev_122.png
#  extracting: facades_dataset_v0/ermoljev_123.png
#  extracting: facades_dataset_v0/ermoljev_124.png
#  extracting: facades_dataset_v0/ermoljev_126.png
#  extracting: facades_dataset_v0/ermoljev_127.png
#  extracting: facades_dataset_v0/ermoljev_128.png
#  extracting: facades_dataset_v0/ermoljev_129.png
#  extracting: facades_dataset_v0/ermoljev_13.png
#  extracting: facades_dataset_v0/ermoljev_130.png
#  extracting: facades_dataset_v0/ermoljev_131.png
#  extracting: facades_dataset_v0/ermoljev_132.png
#  extracting: facades_dataset_v0/ermoljev_133.png
#  extracting: facades_dataset_v0/ermoljev_134.png
#  extracting: facades_dataset_v0/ermoljev_135.png
#  extracting: facades_dataset_v0/ermoljev_136.png
#  extracting: facades_dataset_v0/ermoljev_137.png
#  extracting: facades_dataset_v0/ermoljev_138.png
#  extracting: facades_dataset_v0/ermoljev_139.png
#  extracting: facades_dataset_v0/ermoljev_14.png
#  extracting: facades_dataset_v0/ermoljev_140.png
#  extracting: facades_dataset_v0/ermoljev_141.png
#  extracting: facades_dataset_v0/ermoljev_142.png
#  extracting: facades_dataset_v0/ermoljev_143.png
#  extracting: facades_dataset_v0/ermoljev_144.png
#  extracting: facades_dataset_v0/ermoljev_145.png
#  extracting: facades_dataset_v0/ermoljev_146.png
#  extracting: facades_dataset_v0/ermoljev_147.png
#  extracting: facades_dataset_v0/ermoljev_148.png
#  extracting: facades_dataset_v0/ermoljev_149.png
#  extracting: facades_dataset_v0/ermoljev_15.png
#  extracting: facades_dataset_v0/ermoljev_150.png
#  extracting: facades_dataset_v0/ermoljev_151.png
#  extracting: facades_dataset_v0/ermoljev_152.png
#  extracting: facades_dataset_v0/ermoljev_153.png
#  extracting: facades_dataset_v0/ermoljev_154.png
#  extracting: facades_dataset_v0/ermoljev_155.png
#  extracting: facades_dataset_v0/ermoljev_157.png
#  extracting: facades_dataset_v0/ermoljev_158.png
#  extracting: facades_dataset_v0/ermoljev_159.png
#  extracting: facades_dataset_v0/ermoljev_16.png
#  extracting: facades_dataset_v0/ermoljev_160.png
#  extracting: facades_dataset_v0/ermoljev_161.png
#  extracting: facades_dataset_v0/ermoljev_162.png
#  extracting: facades_dataset_v0/ermoljev_163.png
#  extracting: facades_dataset_v0/ermoljev_164.png
#  extracting: facades_dataset_v0/ermoljev_165.png
#  extracting: facades_dataset_v0/ermoljev_166.png
#  extracting: facades_dataset_v0/ermoljev_167.png
#  extracting: facades_dataset_v0/ermoljev_168.png
#  extracting: facades_dataset_v0/ermoljev_169.png
#  extracting: facades_dataset_v0/ermoljev_17.png
#  extracting: facades_dataset_v0/ermoljev_170.png
#  extracting: facades_dataset_v0/ermoljev_171.png
#  extracting: facades_dataset_v0/ermoljev_172.png
#  extracting: facades_dataset_v0/ermoljev_173.png
#  extracting: facades_dataset_v0/ermoljev_174.png
#  extracting: facades_dataset_v0/ermoljev_175.png
#  extracting: facades_dataset_v0/ermoljev_177.png
#  extracting: facades_dataset_v0/ermoljev_178.png
#  extracting: facades_dataset_v0/ermoljev_179.png
#  extracting: facades_dataset_v0/ermoljev_18.png
#  extracting: facades_dataset_v0/ermoljev_180.png
#  extracting: facades_dataset_v0/ermoljev_181.png
#  extracting: facades_dataset_v0/ermoljev_182.png
#  extracting: facades_dataset_v0/ermoljev_183.png
#  extracting: facades_dataset_v0/ermoljev_185.png
#  extracting: facades_dataset_v0/ermoljev_186.png
#  extracting: facades_dataset_v0/ermoljev_187.png
#  extracting: facades_dataset_v0/ermoljev_188.png
#  extracting: facades_dataset_v0/ermoljev_189.png
#  extracting: facades_dataset_v0/ermoljev_19.png
#  extracting: facades_dataset_v0/ermoljev_190.png
#  extracting: facades_dataset_v0/ermoljev_191.png
#  extracting: facades_dataset_v0/ermoljev_192.png
#  extracting: facades_dataset_v0/ermoljev_193.png
#  extracting: facades_dataset_v0/ermoljev_194.png
#  extracting: facades_dataset_v0/ermoljev_196.png
#  extracting: facades_dataset_v0/ermoljev_197.png
#  extracting: facades_dataset_v0/ermoljev_198.png
#  extracting: facades_dataset_v0/ermoljev_199.png
#  extracting: facades_dataset_v0/ermoljev_20.png
#  extracting: facades_dataset_v0/ermoljev_200.png
#  extracting: facades_dataset_v0/ermoljev_201.png
#  extracting: facades_dataset_v0/ermoljev_202.png
#  extracting: facades_dataset_v0/ermoljev_203.png
#  extracting: facades_dataset_v0/ermoljev_204.png
#  extracting: facades_dataset_v0/ermoljev_205.png
#  extracting: facades_dataset_v0/ermoljev_206.png
#  extracting: facades_dataset_v0/ermoljev_207.png
#  extracting: facades_dataset_v0/ermoljev_208.png
#  extracting: facades_dataset_v0/ermoljev_209.png
#  extracting: facades_dataset_v0/ermoljev_21.png
#  extracting: facades_dataset_v0/ermoljev_210.png
#  extracting: facades_dataset_v0/ermoljev_211.png
#  extracting: facades_dataset_v0/ermoljev_212.png
#  extracting: facades_dataset_v0/ermoljev_213.png
#  extracting: facades_dataset_v0/ermoljev_214.png
#  extracting: facades_dataset_v0/ermoljev_215.png
#  extracting: facades_dataset_v0/ermoljev_216.png
#  extracting: facades_dataset_v0/ermoljev_217.png
#  extracting: facades_dataset_v0/ermoljev_218.png
#  extracting: facades_dataset_v0/ermoljev_219.png
#  extracting: facades_dataset_v0/ermoljev_22.png
#  extracting: facades_dataset_v0/ermoljev_220.png
#  extracting: facades_dataset_v0/ermoljev_221.png
#  extracting: facades_dataset_v0/ermoljev_222.png
#  extracting: facades_dataset_v0/ermoljev_223.png
#  extracting: facades_dataset_v0/ermoljev_224.png
#  extracting: facades_dataset_v0/ermoljev_225.png
#  extracting: facades_dataset_v0/ermoljev_226.png
#  extracting: facades_dataset_v0/ermoljev_227.png
#  extracting: facades_dataset_v0/ermoljev_228.png
#  extracting: facades_dataset_v0/ermoljev_229.png
#  extracting: facades_dataset_v0/ermoljev_23.png
#  extracting: facades_dataset_v0/ermoljev_230.png
#  extracting: facades_dataset_v0/ermoljev_231.png
#  extracting: facades_dataset_v0/ermoljev_232.png
#  extracting: facades_dataset_v0/ermoljev_233.png
#  extracting: facades_dataset_v0/ermoljev_234.png
#  extracting: facades_dataset_v0/ermoljev_235.png
#  extracting: facades_dataset_v0/ermoljev_236.png
#  extracting: facades_dataset_v0/ermoljev_237.png
#  extracting: facades_dataset_v0/ermoljev_238.png
#  extracting: facades_dataset_v0/ermoljev_239.png
#  extracting: facades_dataset_v0/ermoljev_24.png
#  extracting: facades_dataset_v0/ermoljev_240.png
#  extracting: facades_dataset_v0/ermoljev_241.png
#  extracting: facades_dataset_v0/ermoljev_242.png
#  extracting: facades_dataset_v0/ermoljev_243.png
#  extracting: facades_dataset_v0/ermoljev_244.png
#  extracting: facades_dataset_v0/ermoljev_245.png
#  extracting: facades_dataset_v0/ermoljev_246.png
#  extracting: facades_dataset_v0/ermoljev_247.png
#  extracting: facades_dataset_v0/ermoljev_25.png
#  extracting: facades_dataset_v0/ermoljev_26.png
#  extracting: facades_dataset_v0/ermoljev_27.png
#  extracting: facades_dataset_v0/ermoljev_29.png
#  extracting: facades_dataset_v0/ermoljev_3.png
#  extracting: facades_dataset_v0/ermoljev_30.png
#  extracting: facades_dataset_v0/ermoljev_31.png
#  extracting: facades_dataset_v0/ermoljev_33.png
#  extracting: facades_dataset_v0/ermoljev_34.png
#  extracting: facades_dataset_v0/ermoljev_35.png
#  extracting: facades_dataset_v0/ermoljev_36.png
#  extracting: facades_dataset_v0/ermoljev_37.png
#  extracting: facades_dataset_v0/ermoljev_39.png
#  extracting: facades_dataset_v0/ermoljev_4.png
#  extracting: facades_dataset_v0/ermoljev_40.png
#  extracting: facades_dataset_v0/ermoljev_41.png
#  extracting: facades_dataset_v0/ermoljev_42.png
#  extracting: facades_dataset_v0/ermoljev_43.png
#  extracting: facades_dataset_v0/ermoljev_44.png
#  extracting: facades_dataset_v0/ermoljev_45.png
#  extracting: facades_dataset_v0/ermoljev_46.png
#  extracting: facades_dataset_v0/ermoljev_47.png
#  extracting: facades_dataset_v0/ermoljev_48.png
#  extracting: facades_dataset_v0/ermoljev_49.png
#  extracting: facades_dataset_v0/ermoljev_5.png
#  extracting: facades_dataset_v0/ermoljev_50.png
#  extracting: facades_dataset_v0/ermoljev_51.png
#  extracting: facades_dataset_v0/ermoljev_52.png
#  extracting: facades_dataset_v0/ermoljev_53.png
#  extracting: facades_dataset_v0/ermoljev_54.png
#  extracting: facades_dataset_v0/ermoljev_55.png
#  extracting: facades_dataset_v0/ermoljev_56.png
#  extracting: facades_dataset_v0/ermoljev_57.png
#  extracting: facades_dataset_v0/ermoljev_58.png
#  extracting: facades_dataset_v0/ermoljev_59.png
#  extracting: facades_dataset_v0/ermoljev_6.png
#  extracting: facades_dataset_v0/ermoljev_60.png
#  extracting: facades_dataset_v0/ermoljev_61.png
#  extracting: facades_dataset_v0/ermoljev_63.png
#  extracting: facades_dataset_v0/ermoljev_64.png
#  extracting: facades_dataset_v0/ermoljev_65.png
#  extracting: facades_dataset_v0/ermoljev_66.png
#  extracting: facades_dataset_v0/ermoljev_67.png
#  extracting: facades_dataset_v0/ermoljev_68.png
#  extracting: facades_dataset_v0/ermoljev_69.png
#  extracting: facades_dataset_v0/ermoljev_7.png
#  extracting: facades_dataset_v0/ermoljev_70.png
#  extracting: facades_dataset_v0/ermoljev_71.png
#  extracting: facades_dataset_v0/ermoljev_72.png
#  extracting: facades_dataset_v0/ermoljev_73.png
#  extracting: facades_dataset_v0/ermoljev_74.png
#  extracting: facades_dataset_v0/ermoljev_75.png
#  extracting: facades_dataset_v0/ermoljev_76.png
#  extracting: facades_dataset_v0/ermoljev_77.png
#  extracting: facades_dataset_v0/ermoljev_78.png
#  extracting: facades_dataset_v0/ermoljev_79.png
#  extracting: facades_dataset_v0/ermoljev_8.png
#  extracting: facades_dataset_v0/ermoljev_80.png
#  extracting: facades_dataset_v0/ermoljev_81.png
#  extracting: facades_dataset_v0/ermoljev_82.png
#  extracting: facades_dataset_v0/ermoljev_83.png
#  extracting: facades_dataset_v0/ermoljev_84.png
#  extracting: facades_dataset_v0/ermoljev_85.png
#  extracting: facades_dataset_v0/ermoljev_86.png
#  extracting: facades_dataset_v0/ermoljev_88.png
#  extracting: facades_dataset_v0/ermoljev_89.png
#  extracting: facades_dataset_v0/ermoljev_9.png
#  extracting: facades_dataset_v0/ermoljev_90.png
#  extracting: facades_dataset_v0/ermoljev_91.png
#  extracting: facades_dataset_v0/ermoljev_92.png
#  extracting: facades_dataset_v0/ermoljev_93.png
#  extracting: facades_dataset_v0/ermoljev_94.png
#  extracting: facades_dataset_v0/ermoljev_95.png
#  extracting: facades_dataset_v0/ermoljev_96.png
#  extracting: facades_dataset_v0/ermoljev_97.png
#  extracting: facades_dataset_v0/ermoljev_98.png
#  extracting: facades_dataset_v0/ermoljev_99.png
#  extracting: facades_dataset_v0/kalachev_facade_0001.png
#  extracting: facades_dataset_v0/kalachev_facade_0002.png
#  extracting: facades_dataset_v0/kalachev_facade_0003.png
#  extracting: facades_dataset_v0/kalachev_facade_0004.png
#  extracting: facades_dataset_v0/kalachev_facade_0005.png
#  extracting: facades_dataset_v0/kalachev_facade_0006.png
#  extracting: facades_dataset_v0/kalachev_facade_0007.png
#  extracting: facades_dataset_v0/kalachev_facade_0008.png
#  extracting: facades_dataset_v0/kalachev_facade_0009.png
#  extracting: facades_dataset_v0/kalachev_facade_0010.png
#  extracting: facades_dataset_v0/kalachev_facade_0011.png
#  extracting: facades_dataset_v0/kalachev_facade_0012.png
#  extracting: facades_dataset_v0/kalachev_facade_0013.png
#  extracting: facades_dataset_v0/kalachev_facade_0014.png
#  extracting: facades_dataset_v0/kalachev_facade_0015.png
#  extracting: facades_dataset_v0/kalachev_facade_0016.png
#  extracting: facades_dataset_v0/kalachev_facade_0017.png
#  extracting: facades_dataset_v0/kalachev_facade_0018.png
#  extracting: facades_dataset_v0/kalachev_facade_0019.png
#  extracting: facades_dataset_v0/kalachev_facade_0020.png
#  extracting: facades_dataset_v0/kalachev_facade_0021.png
#  extracting: facades_dataset_v0/kalachev_facade_0022.png
#  extracting: facades_dataset_v0/kalachev_facade_0023.png
#  extracting: facades_dataset_v0/kalachev_facade_0024.png
#  extracting: facades_dataset_v0/kalachev_facade_0025.png
#  extracting: facades_dataset_v0/kalachev_facade_0026.png
#  extracting: facades_dataset_v0/kalachev_facade_0027.png
#  extracting: facades_dataset_v0/kalachev_facade_0028.png
#  extracting: facades_dataset_v0/kalachev_facade_0029.png
#  extracting: facades_dataset_v0/kalachev_facade_0030.png
#  extracting: facades_dataset_v0/kalachev_facade_0032.png
#  extracting: facades_dataset_v0/kalachev_facade_0033.png
#  extracting: facades_dataset_v0/kalachev_facade_0034.png
#  extracting: facades_dataset_v0/kalachev_facade_0036.png
#  extracting: facades_dataset_v0/kalachev_facade_0037.png
#  extracting: facades_dataset_v0/kalachev_facade_0040.png
#  extracting: facades_dataset_v0/kalachev_facade_0041.png
#  extracting: facades_dataset_v0/kalachev_facade_0042.png
#  extracting: facades_dataset_v0/kalachev_facade_0045.png
#  extracting: facades_dataset_v0/kalachev_facade_0046.png
#  extracting: facades_dataset_v0/kalachev_facade_0047.png
#  extracting: facades_dataset_v0/kalachev_facade_0048.png
#  extracting: facades_dataset_v0/kalachev_facade_0049.png
#  extracting: facades_dataset_v0/kalachev_facade_0050.png
#  extracting: facades_dataset_v0/kalachev_facade_0051.png
#  extracting: facades_dataset_v0/kalachev_facade_0052.png
#  extracting: facades_dataset_v0/kalachev_facade_0053.png
#  extracting: facades_dataset_v0/kalachev_facade_0054.png
#  extracting: facades_dataset_v0/kalachev_facade_0055.png
#  extracting: facades_dataset_v0/kalachev_facade_0056.png
#  extracting: facades_dataset_v0/kalachev_facade_0057.png
#  extracting: facades_dataset_v0/kalachev_facade_0058.png
#  extracting: facades_dataset_v0/kalachev_facade_0059.png
#  extracting: facades_dataset_v0/kalachev_facade_0060.png
#  extracting: facades_dataset_v0/kalachev_facade_0061.png
#  extracting: facades_dataset_v0/kalachev_facade_0062.png
#  extracting: facades_dataset_v0/kalachev_facade_0063.png
#  extracting: facades_dataset_v0/kalachev_facade_0064.png
#  extracting: facades_dataset_v0/kalachev_facade_0065.png
#  extracting: facades_dataset_v0/kalachev_facade_0066.png
#  extracting: facades_dataset_v0/kalachev_facade_0067.png
#  extracting: facades_dataset_v0/kalachev_facade_0068.png
#  extracting: facades_dataset_v0/kalachev_facade_0069.png
#  extracting: facades_dataset_v0/kalachev_facade_0070.png
#  extracting: facades_dataset_v0/kalachev_facade_0071.png
#  extracting: facades_dataset_v0/kalachev_facade_0074.png
#  extracting: facades_dataset_v0/kalachev_facade_0075.png
#  extracting: facades_dataset_v0/kalachev_facade_0080.png
#  extracting: facades_dataset_v0/kalachev_facade_0081.png
#  extracting: facades_dataset_v0/kalachev_facade_0082.png
#  extracting: facades_dataset_v0/kalachev_facade_0083.png
#  extracting: facades_dataset_v0/kalachev_facade_0084.png
#  extracting: facades_dataset_v0/kalachev_facade_0085.png
#  extracting: facades_dataset_v0/kalachev_facade_0086.png
#  extracting: facades_dataset_v0/kalachev_facade_0087.png
#  extracting: facades_dataset_v0/kalachev_facade_0088.png
#  extracting: facades_dataset_v0/kalachev_facade_0089.png
#  extracting: facades_dataset_v0/kalachev_facade_0102.png
#  extracting: facades_dataset_v0/kalachev_facade_0103.png
#  extracting: facades_dataset_v0/kalachev_facade_0104.png
#  extracting: facades_dataset_v0/kalachev_facade_0105.png
#  extracting: facades_dataset_v0/kalachev_facade_0106.png
#  extracting: facades_dataset_v0/kalachev_facade_0107.png
#  extracting: facades_dataset_v0/kalachev_facade_0108.png
#  extracting: facades_dataset_v0/kalachev_facade_0109.png
#  extracting: facades_dataset_v0/kalachev_facade_0110.png
#  extracting: facades_dataset_v0/kalachev_facade_0111.png
#  extracting: facades_dataset_v0/kalachev_facade_0112.png
#  extracting: facades_dataset_v0/kalachev_facade_0113.png
#  extracting: facades_dataset_v0/kalachev_facade_0114.png
#  extracting: facades_dataset_v0/kalachev_facade_0115.png
#  extracting: facades_dataset_v0/kalachev_facade_0116.png
#  extracting: facades_dataset_v0/kalachev_facade_0117.png
#  extracting: facades_dataset_v0/kalachev_facade_0118.png
#  extracting: facades_dataset_v0/kalachev_facade_0119.png
#  extracting: facades_dataset_v0/kalachev_facade_0120.png
#  extracting: facades_dataset_v0/kalachev_facade_0121.png
#  extracting: facades_dataset_v0/kalachev_facade_0122.png
#  extracting: facades_dataset_v0/kalachev_facade_0123.png
#  extracting: facades_dataset_v0/kalachev_facade_0124.png
#  extracting: facades_dataset_v0/kalachev_facade_0125.png
#  extracting: facades_dataset_v0/kalachev_facade_0126.png
#  extracting: facades_dataset_v0/kalachev_facade_0131.png
#  extracting: facades_dataset_v0/kalachev_facade_0132.png
#  extracting: facades_dataset_v0/kalachev_facade_0133.png
#  extracting: facades_dataset_v0/kalachev_facade_0134.png
#  extracting: facades_dataset_v0/kalachev_facade_0135.png
#  extracting: facades_dataset_v0/kalachev_facade_0136.png
#  extracting: facades_dataset_v0/kalachev_facade_0137.png
#  extracting: facades_dataset_v0/kalachev_facade_0138.png
#  extracting: facades_dataset_v0/kalachev_facade_0139.png
#  extracting: facades_dataset_v0/kalachev_facade_0140.png
#  extracting: facades_dataset_v0/kalachev_facade_0141.png
#  extracting: facades_dataset_v0/kalachev_facade_0142.png
#  extracting: facades_dataset_v0/kalachev_facade_0143.png
#  extracting: facades_dataset_v0/kalachev_facade_0144.png
#  extracting: facades_dataset_v0/kalachev_facade_0145.png
#  extracting: facades_dataset_v0/kalachev_facade_0146.png
#  extracting: facades_dataset_v0/kalachev_facade_0147.png
#  extracting: facades_dataset_v0/kalachev_facade_0148.png
#  extracting: facades_dataset_v0/kalachev_facade_0149.png
#  extracting: facades_dataset_v0/kalachev_facade_0150.png
#  extracting: facades_dataset_v0/kalachev_facade_0151.png
#  extracting: facades_dataset_v0/kalachev_facade_0152.png
#  extracting: facades_dataset_v0/kalachev_facade_0153.png
#  extracting: facades_dataset_v0/kalachev_facade_0154.png
#  extracting: facades_dataset_v0/kalachev_facade_0155.png
#  extracting: facades_dataset_v0/kalachev_facade_0156.png
#  extracting: facades_dataset_v0/kalachev_facade_0157.png
#  extracting: facades_dataset_v0/kalachev_facade_0158.png
#  extracting: facades_dataset_v0/kalachev_facade_0159.png
#  extracting: facades_dataset_v0/kalachev_facade_0160.png
#  extracting: facades_dataset_v0/kalachev_facade_0161.png
#  extracting: facades_dataset_v0/kalachev_facade_0162.png
#  extracting: facades_dataset_v0/kalachev_facade_0163.png
#  extracting: facades_dataset_v0/kalachev_facade_0165.png
#  extracting: facades_dataset_v0/kalachev_facade_0166.png
#  extracting: facades_dataset_v0/kalachev_facade_0167.png
#  extracting: facades_dataset_v0/kalachev_facade_0168.png
#  extracting: facades_dataset_v0/kalachev_facade_0169.png
#  extracting: facades_dataset_v0/kalachev_facade_0170.png
#  extracting: facades_dataset_v0/kalachev_facade_0171.png
#  extracting: facades_dataset_v0/kalachev_facade_0172.png
#  extracting: facades_dataset_v0/kalachev_facade_0173.png
#  extracting: facades_dataset_v0/kalachev_facade_0174.png
#  extracting: facades_dataset_v0/kalachev_facade_0175.png
#  extracting: facades_dataset_v0/kalachev_facade_0176.png
#  extracting: facades_dataset_v0/kalachev_facade_0177.png
#  extracting: facades_dataset_v0/kalachev_facade_0178.png
#  extracting: facades_dataset_v0/kalachev_facade_0179.png
#  extracting: facades_dataset_v0/kalachev_facade_0180.png
#  extracting: facades_dataset_v0/kalachev_facade_0181.png
#  extracting: facades_dataset_v0/kalachev_facade_0182.png
#  extracting: facades_dataset_v0/kalachev_facade_0183.png
#  extracting: facades_dataset_v0/kalachev_facade_0184.png
#  extracting: facades_dataset_v0/kalachev_facade_0185.png
#  extracting: facades_dataset_v0/kalachev_facade_0186.png
#  extracting: facades_dataset_v0/kalachev_facade_0187.png
#  extracting: facades_dataset_v0/kalachev_facade_0188.png
#  extracting: facades_dataset_v0/kalachev_facade_0189.png
#  extracting: facades_dataset_v0/kalachev_facade_0190.png
#  extracting: facades_dataset_v0/kalachev_facade_0191.png
#  extracting: facades_dataset_v0/kalachev_facade_0193.png
#  extracting: facades_dataset_v0/kalachev_facade_0194.png
#  extracting: facades_dataset_v0/kalachev_facade_0195.png
#  extracting: facades_dataset_v0/kalachev_facade_0196.png
#  extracting: facades_dataset_v0/kalachev_facade_0197.png
#  extracting: facades_dataset_v0/kalachev_facade_0198.png
#  extracting: facades_dataset_v0/kalachev_facade_0199.png
#  extracting: facades_dataset_v0/kalachev_facade_0200.png
#  extracting: facades_dataset_v0/kalachev_facade_0201.png
#  extracting: facades_dataset_v0/kalachev_facade_0202.png
#  extracting: facades_dataset_v0/kalachev_facade_0203.png
#  extracting: facades_dataset_v0/kalachev_facade_0204.png
#  extracting: facades_dataset_v0/kalachev_facade_0205.png
#  extracting: facades_dataset_v0/kalachev_facade_0206.png
#  extracting: facades_dataset_v0/kalachev_facade_0207.png
#  extracting: facades_dataset_v0/kalachev_facade_0208.png
#  extracting: facades_dataset_v0/kalachev_facade_0209.png
#  extracting: facades_dataset_v0/kalachev_facade_0210.png
#  extracting: facades_dataset_v0/kalachev_facade_0211.png
#  extracting: facades_dataset_v0/kalachev_facade_0212.png
#  extracting: facades_dataset_v0/kalachev_facade_0213.png
#  extracting: facades_dataset_v0/kalachev_facade_0214.png
#  extracting: facades_dataset_v0/kalachev_facade_0215.png
#  extracting: facades_dataset_v0/kalachev_facade_0216.png
#  extracting: facades_dataset_v0/kalachev_facade_0217.png
#  extracting: facades_dataset_v0/kalachev_facade_0218.png
#  extracting: facades_dataset_v0/kalachev_facade_0219.png
#  extracting: facades_dataset_v0/kalachev_facade_0220.png
#  extracting: facades_dataset_v0/kalachev_facade_0221.png
#  extracting: facades_dataset_v0/kalachev_facade_0222.png
#  extracting: facades_dataset_v0/kalachev_facade_0223.png
#  extracting: facades_dataset_v0/kalachev_facade_0224.png
#  extracting: facades_dataset_v0/kalachev_facade_0225.png
#  extracting: facades_dataset_v0/kalachev_facade_0226.png
#  extracting: facades_dataset_v0/kalachev_facade_0227.png
#  extracting: facades_dataset_v0/kalachev_facade_0228.png
#  extracting: facades_dataset_v0/kalachev_facade_0229.png
#  extracting: facades_dataset_v0/kalachev_facade_0230.png
#  extracting: facades_dataset_v0/kalachev_facade_0231.png
#  extracting: facades_dataset_v0/kalachev_facade_0232.png
#  extracting: facades_dataset_v0/kalachev_facade_0233.png
#  extracting: facades_dataset_v0/kalachev_facade_0234.png
#  extracting: facades_dataset_v0/kalachev_facade_0236.png
#  extracting: facades_dataset_v0/kalachev_facade_0237.png
#  extracting: facades_dataset_v0/kalachev_facade_0238.png
#  extracting: facades_dataset_v0/kalachev_facade_0239.png
#  extracting: facades_dataset_v0/kalachev_facade_0240.png
#  extracting: facades_dataset_v0/kalachev_facade_0241.png
#  extracting: facades_dataset_v0/kalachev_facade_0242.png
#  extracting: facades_dataset_v0/kalachev_facade_0243.png
#  extracting: facades_dataset_v0/kalachev_facade_0244.png
#  extracting: facades_dataset_v0/kalachev_facade_0245.png
#  extracting: facades_dataset_v0/kalachev_facade_0246.png
#  extracting: facades_dataset_v0/kalachev_facade_0247.png
#  extracting: facades_dataset_v0/kalachev_facade_0248.png
#  extracting: facades_dataset_v0/kalachev_facade_0249.png
#  extracting: facades_dataset_v0/kalachev_facade_0250.png
#  extracting: facades_dataset_v0/kalachev_facade_0251.png
#  extracting: facades_dataset_v0/kalachev_facade_0252.png
#  extracting: facades_dataset_v0/kalachev_facade_0253.png
#  extracting: facades_dataset_v0/kalachev_facade_0254.png
#  extracting: facades_dataset_v0/kalachev_facade_0255.png
#  extracting: facades_dataset_v0/kalachev_facade_0256.png
#  extracting: facades_dataset_v0/kalachev_facade_0257.png
#  extracting: facades_dataset_v0/kalachev_facade_0258.png
#  extracting: facades_dataset_v0/kalachev_facade_0259.png
#  extracting: facades_dataset_v0/kalachev_facade_0260.png
#  extracting: facades_dataset_v0/kalachev_facade_0261.png
#  extracting: facades_dataset_v0/kalachev_facade_0262.png
#  extracting: facades_dataset_v0/kalachev_facade_0263.png
#  extracting: facades_dataset_v0/kalachev_facade_0264.png
#  extracting: facades_dataset_v0/kalachev_facade_0265.png
#  extracting: facades_dataset_v0/kalachev_facade_0266.png
#  extracting: facades_dataset_v0/kalachev_facade_0267.png
#  extracting: facades_dataset_v0/kalachev_facade_0268.png
#  extracting: facades_dataset_v0/kalachev_facade_0269.png
#  extracting: facades_dataset_v0/kalachev_facade_0270.png
#  extracting: facades_dataset_v0/kalachev_facade_0271.png
#  extracting: facades_dataset_v0/kalachev_facade_0272.png
#  extracting: facades_dataset_v0/kalachev_facade_0273.png
#  extracting: facades_dataset_v0/kalachev_facade_0274.png
#  extracting: facades_dataset_v0/kalachev_facade_0275.png
#  extracting: facades_dataset_v0/kalachev_facade_0276.png
#  extracting: facades_dataset_v0/kalachev_facade_0277.png
#  extracting: facades_dataset_v0/kalachev_facade_0278.png
#  extracting: facades_dataset_v0/kalachev_facade_0279.png
#  extracting: facades_dataset_v0/kalachev_facade_0280.png
#  extracting: facades_dataset_v0/kalachev_facade_0281.png
#  extracting: facades_dataset_v0/kalachev_facade_0282.png
#  extracting: facades_dataset_v0/kalachev_facade_0283.png
#  extracting: facades_dataset_v0/kalachev_facade_0284.png
#  extracting: facades_dataset_v0/kalachev_facade_0285.png
#  extracting: facades_dataset_v0/kalachev_facade_0286.png
#  extracting: facades_dataset_v0/lebedeva_img235.png
#  extracting: facades_dataset_v0/lebedeva_img239.png
#  extracting: facades_dataset_v0/lebedeva_img246.png
#  extracting: facades_dataset_v0/lebedeva_img250.png
#  extracting: facades_dataset_v0/lebedeva_img254.png
#  extracting: facades_dataset_v0/lebedeva_img262.png
#  extracting: facades_dataset_v0/lebedeva_img266.png
#  extracting: facades_dataset_v0/lebedeva_img289.png
#  extracting: facades_dataset_v0/lebedeva_img293.png
#  extracting: facades_dataset_v0/lebedeva_img308.png
#  extracting: facades_dataset_v0/lebedeva_img312.png
#  extracting: facades_dataset_v0/varhushev_1.png
#  extracting: facades_dataset_v0/varhushev_1_10.png
#  extracting: facades_dataset_v0/varhushev_1_11.png
#  extracting: facades_dataset_v0/varhushev_1_2.png
#  extracting: facades_dataset_v0/varhushev_1_3.png
#  extracting: facades_dataset_v0/varhushev_1_4.png
#  extracting: facades_dataset_v0/varhushev_1_5.png
#  extracting: facades_dataset_v0/varhushev_1_9.png
#  extracting: facades_dataset_v0/varhushev_10.png
#  extracting: facades_dataset_v0/varhushev_10_1.png
#  extracting: facades_dataset_v0/varhushev_11.png
#  extracting: facades_dataset_v0/varhushev_11_1.png
#  extracting: facades_dataset_v0/varhushev_12.png
#  extracting: facades_dataset_v0/varhushev_12_1.png
#  extracting: facades_dataset_v0/varhushev_13.png
#  extracting: facades_dataset_v0/varhushev_13_1.png
#  extracting: facades_dataset_v0/varhushev_14.png
#  extracting: facades_dataset_v0/varhushev_14_1.png
#  extracting: facades_dataset_v0/varhushev_15.png
#  extracting: facades_dataset_v0/varhushev_2.png
#  extracting: facades_dataset_v0/varhushev_2_1.png
#  extracting: facades_dataset_v0/varhushev_2_11.png
#  extracting: facades_dataset_v0/varhushev_2_3.png
#  extracting: facades_dataset_v0/varhushev_2_4.png
#  extracting: facades_dataset_v0/varhushev_2_5.png
#  extracting: facades_dataset_v0/varhushev_2_8.png
#  extracting: facades_dataset_v0/varhushev_2_9.png
#  extracting: facades_dataset_v0/varhushev_3_1.png
#  extracting: facades_dataset_v0/varhushev_3_10.png
#  extracting: facades_dataset_v0/varhushev_3_11.png
#  extracting: facades_dataset_v0/varhushev_3_2.png
#  extracting: facades_dataset_v0/varhushev_3_3.png
#  extracting: facades_dataset_v0/varhushev_3_4.png
#  extracting: facades_dataset_v0/varhushev_3_5.png
#  extracting: facades_dataset_v0/varhushev_3_8.png
#  extracting: facades_dataset_v0/varhushev_3_9.png
#  extracting: facades_dataset_v0/varhushev_4.png
#  extracting: facades_dataset_v0/varhushev_4_1.png
#  extracting: facades_dataset_v0/varhushev_4_11.png
#  extracting: facades_dataset_v0/varhushev_4_2.png
#  extracting: facades_dataset_v0/varhushev_4_3.png
#  extracting: facades_dataset_v0/varhushev_4_4.png
#  extracting: facades_dataset_v0/varhushev_4_5.png
#  extracting: facades_dataset_v0/varhushev_4_8.png
#  extracting: facades_dataset_v0/varhushev_4_9.png
#  extracting: facades_dataset_v0/varhushev_5.png
#  extracting: facades_dataset_v0/varhushev_5_1.png
#  extracting: facades_dataset_v0/varhushev_5_3.png
#  extracting: facades_dataset_v0/varhushev_5_5.png
#  extracting: facades_dataset_v0/varhushev_6.png
#  extracting: facades_dataset_v0/varhushev_6_1.png
#  extracting: facades_dataset_v0/varhushev_6_4.png
#  extracting: facades_dataset_v0/varhushev_7.png
#  extracting: facades_dataset_v0/varhushev_7_1.png
#  extracting: facades_dataset_v0/varhushev_7_2.png
#  extracting: facades_dataset_v0/varhushev_7_4.png
#  extracting: facades_dataset_v0/varhushev_8.png
#  extracting: facades_dataset_v0/varhushev_8_1.png
#  extracting: facades_dataset_v0/varhushev_9.png
#  extracting: facades_dataset_v0/varhushev_9_1.png

# %% [markdown]
# # Задание 1 (15 баллов)
#
# * Найдите или обучите сегментатор окон, дверей и балконов на фасадах зданий (5
# баллов каждый из интернета или 15 баллов свой).
# * Тестовый датасет https://disk.yandex.com/d/VFEIGpGh-MkvwA
# * Интересует хорошее качество (map@0.5 >= 0.6), чтобы в дальнейшем можно было
# передать на валидацию разметки.

# %%
# %pip install -q transformers accelerate Pillow tqdm

# %% [markdown]
# ## SegFormer-B5, fine-tuned on CMP Facades

# %%
import os, random
import numpy as np
import torch
import torch.nn.functional as F
from pathlib import Path
from PIL import Image
from tqdm.auto import tqdm
from transformers import SegformerImageProcessor, SegformerForSemanticSegmentation
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

MODEL_ID   = "Xpitfire/segformer-finetuned-segments-cmp-facade"
IMAGE_DIR  = "/content/facades_dataset_v0"          # ← путь к датасету
OUTPUT_DIR = "/content/segformer_output"
DEVICE     = "cuda" if torch.cuda.is_available() else "cpu"

LABELS = {
    0: "background", 1: "facade",  2: "molding", 3: "cornice",
    4: "pillar",     5: "window",  6: "door",    7: "sill",
    8: "blind",      9: "balcony", 10: "shop",   11: "deco",
    12: "unknown",
}
PALETTE = np.array([
    [0,0,0], [128,128,128], [139,90,43],  [255,165,0],
    [0,128,0], [0,0,255],  [255,0,0],    [255,255,0],
    [0,255,255], [255,0,255], [128,0,128], [0,255,0],
    [64,64,64],
], dtype=np.uint8)

# %%
processor = SegformerImageProcessor.from_pretrained(MODEL_ID)
model = SegformerForSemanticSegmentation.from_pretrained(MODEL_ID).eval().to(DEVICE)
print(f"Loaded on {DEVICE} | classes: {model.config.num_labels}")
# Out:
# preprocessor_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/image_processing_base.py:370: UserWarning: The following named arguments are not valid for `SegformerImageProcessor.__init__` and were ignored: 'feature_extractor_type', 'reduce_labels'
#   image_processor = cls(**image_processor_dict)
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/14.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]
# Loaded on cuda | classes: 13

# %%
def predict(image: Image.Image) -> np.ndarray:
    inputs = processor(images=image, return_tensors="pt").to(DEVICE)
    with torch.no_grad():
        logits = model(**inputs).logits
    upsampled = F.interpolate(logits, size=(image.size[1], image.size[0]),
                              mode="bilinear", align_corners=False)
    return upsampled.argmax(dim=1).squeeze(0).cpu().numpy().astype(np.int64)

def to_rgb(seg: np.ndarray) -> np.ndarray:
    seg_clipped = np.clip(seg, 0, len(PALETTE) - 1)
    return PALETTE[seg_clipped]

def coverage(seg: np.ndarray) -> dict:
    total = seg.size
    ids, counts = np.unique(seg, return_counts=True)
    return {LABELS.get(int(i), f"cls_{i}"): round(c / total * 100, 2)
            for i, c in zip(ids, counts)}

def blend(image: Image.Image, seg: np.ndarray, alpha: float = 0.5) -> np.ndarray:
    return (alpha * np.array(image) + (1 - alpha) * to_rgb(seg)).clip(0,255).astype(np.uint8)

# %%
paths = sorted(Path(IMAGE_DIR).glob("*.png"))
sample = random.sample(paths, 5)

for img_path in sample:
    image = Image.open(img_path).convert("RGB")
    seg   = predict(image)
    cov   = coverage(seg)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(img_path.name, fontsize=11)
    axes[0].imshow(image);              axes[0].set_title("Original");  axes[0].axis("off")
    axes[1].imshow(to_rgb(seg));        axes[1].set_title("Mask");       axes[1].axis("off")
    axes[2].imshow(blend(image, seg));  axes[2].set_title("Overlay");    axes[2].axis("off")

    patches = [mpatches.Patch(color=PALETTE[min(i, len(PALETTE)-1)]/255.,
                               label=f"{LABELS.get(int(i), f'cls_{i}')} {cov.get(LABELS.get(int(i), f'cls_{i}'), 0):.1f}%")
               for i in np.unique(seg)]
    fig.legend(handles=patches, loc="lower center", ncol=6, fontsize=8, bbox_to_anchor=(0.5, -0.04))
    plt.tight_layout()
    plt.show()

    print(f"{img_path.name}  |  "
          + "  ".join(f"{c}: {cov.get(c, 0):.1f}%" for c in ["window","door","balcony"]))
# Out:
# kalachev_facade_0003.png  |  window: 0.0%  door: 0.1%  balcony: 0.0%
# ermoljev_139.png  |  window: 0.1%  door: 1.4%  balcony: 0.0%
# ermoljev_40.png  |  window: 0.0%  door: 0.0%  balcony: 0.0%
# drozdov_╨Р╨У╨Ю_╨б╨╡╨▓╨╡╤А╨╜╨░╤П ╤Б╨░╨│╨░.__╤Б╨╢╨░╤В╤Л╨╕╠Ж-47_4.png  |  window: 0.0%  door: 0.0%  balcony: 0.0%
# kalachev_facade_0236.png  |  window: 0.0%  door: 0.0%  balcony: 0.0%

# %%
mask_dir    = Path(OUTPUT_DIR) / "masks"
overlay_dir = Path(OUTPUT_DIR) / "overlays"
mask_dir.mkdir(parents=True, exist_ok=True)
overlay_dir.mkdir(parents=True, exist_ok=True)

csv_rows = ["filename," + ",".join(LABELS.values())]

for img_path in tqdm(paths, desc="Inference"):
    try:
        image = Image.open(img_path).convert("RGB")
        seg   = predict(image)

        Image.fromarray(seg.astype(np.uint8), mode="L").save(
            mask_dir / f"{img_path.stem}_mask.png")

        Image.fromarray(blend(image, seg)).save(
            overlay_dir / f"{img_path.stem}_overlay.png")

        total = seg.size
        row = [img_path.name] + [str(round(np.sum(seg == i) / total * 100, 4))
                                  for i in range(len(LABELS))]
        csv_rows.append(",".join(row))

    except Exception as e:
        print(f"ERROR {img_path.name}: {e}")

(Path(OUTPUT_DIR) / "coverage.csv").write_text("\n".join(csv_rows))
print(f"\nDone. {len(paths)} images → {OUTPUT_DIR}")
print(f"  masks/     — grayscale, pixel = class index [0-12]")
print(f"  overlays/  — RGB blend")
print(f"  coverage.csv")
# Out:
# Inference:   0%|          | 0/697 [00:00<?, ?it/s]
# /tmp/ipykernel_2476/1898298016.py:13: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   Image.fromarray(seg.astype(np.uint8), mode="L").save(
# Done. 697 images → /content/segformer_output
#   masks/     — grayscale, pixel = class index [0-12]
#   overlays/  — RGB blend
#   coverage.csv

# %% [markdown]
# ## Grounded SAM 2 (Grounding DINO + SAM 2.1)

# %%
# %pip install -q transformers accelerate sam2 Pillow tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.9 MB/s eta 0:00:00
#   Building wheel for sam2 (pyproject.toml) ... done
#   Building wheel for iopath (setup.py) ... done

# %%
# %% Cell 2 — Imports & config
import json, random
from pathlib import Path
import numpy as np
import torch
from PIL import Image, ImageDraw
from tqdm import tqdm
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection
from sam2.sam2_image_predictor import SAM2ImagePredictor
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

GDINO_ID       = "IDEA-Research/grounding-dino-base"
SAM2_ID        = "facebook/sam2.1-hiera-large"
IMAGE_DIR      = "/content/facades_dataset_v0"
OUTPUT_DIR     = "/content/gsam2_output"
DEVICE         = "cuda" if torch.cuda.is_available() else "cpu"

TEXT_PROMPT    = "window . door . balcony ."
BOX_THRESHOLD  = 0.30
TEXT_THRESHOLD = 0.25
SAM2_BOX_BATCH = 8

CLASS_COLORS   = {"window": (0, 100, 255), "door": (220, 50, 50), "balcony": (50, 200, 50)}
DEFAULT_COLOR  = (180, 180, 0)

# %%
# Load models
gdino_processor = AutoProcessor.from_pretrained(GDINO_ID)
gdino_model     = AutoModelForZeroShotObjectDetection.from_pretrained(GDINO_ID).to(DEVICE)
sam2_predictor  = SAM2ImagePredictor.from_pretrained(SAM2_ID)
print(f"Models loaded on {DEVICE}")

# Helpers
def detect(image: Image.Image):
    inputs = gdino_processor(
        images=image,
        text=[[c.strip() for c in TEXT_PROMPT.replace(".", "").split()]],
        return_tensors="pt",
    ).to(DEVICE)
    with torch.no_grad():
        outputs = gdino_model(**inputs)
    results = gdino_processor.post_process_grounded_object_detection(
        outputs, inputs.input_ids,
        threshold=BOX_THRESHOLD,
        text_threshold=TEXT_THRESHOLD,
        target_sizes=[image.size[::-1]],
    )[0]
    return results["boxes"].cpu().numpy(), results["scores"].cpu().numpy(), results["labels"]


def segment(image: Image.Image, boxes: np.ndarray) -> np.ndarray:
    """SAM 2.1 с батчингом боксов — предотвращает OOM на изображениях с большим числом объектов"""
    if len(boxes) == 0:
        H, W = image.size[1], image.size[0]
        return np.zeros((0, H, W), dtype=bool)

    img_arr = np.array(image.convert("RGB"))
    all_masks = []

    with torch.inference_mode(), torch.autocast(DEVICE, dtype=torch.bfloat16):
        sam2_predictor.set_image(img_arr)
        for i in range(0, len(boxes), SAM2_BOX_BATCH):
            batch = boxes[i : i + SAM2_BOX_BATCH]
            masks, _, _ = sam2_predictor.predict(
                point_coords=None,
                point_labels=None,
                box=batch,
                multimask_output=False,
            )
            if masks.ndim == 4:
                masks = masks[:, 0]
            all_masks.append(masks.astype(bool))
            torch.cuda.empty_cache()

    return np.concatenate(all_masks, axis=0)


def color_for(label: str):
    for k, v in CLASS_COLORS.items():
        if k in label.lower():
            return v
    return DEFAULT_COLOR


def draw_overlay(image: Image.Image, masks, labels, scores) -> Image.Image:
    canvas = np.array(image.convert("RGB"), dtype=np.float32)
    for mask, label in zip(masks, labels):
        color = np.array(color_for(label), dtype=np.float32)
        canvas[mask] = canvas[mask] * 0.45 + color * 0.55
    result = Image.fromarray(canvas.clip(0, 255).astype(np.uint8))
    draw = ImageDraw.Draw(result)
    for mask, label, score in zip(masks, labels, scores):
        ys, xs = np.where(mask)
        if len(xs) == 0:
            continue
        x0, y0, x1, y1 = xs.min(), ys.min(), xs.max(), ys.max()
        c = color_for(label)
        draw.rectangle([x0, y0, x1, y1], outline=c, width=2)
        draw.text((x0 + 2, y0 + 2), f"{label} {score:.2f}", fill=c)
    return result


def mask_to_rle(mask: np.ndarray) -> dict:
    flat = mask.flatten(order="F").astype(np.uint8)
    counts, prev, run = [], 0, 0
    for v in flat:
        if v == prev:
            run += 1
        else:
            counts.append(run); run = 1; prev = v
    counts.append(run)
    return {"counts": counts, "size": list(mask.shape)}

# %%
# Visual test on 5 random images
paths  = sorted(Path(IMAGE_DIR).glob("*.png"))
assert len(paths) > 0, f"No PNG files in {IMAGE_DIR}"
sample = random.sample(paths, min(5, len(paths)))

for img_path in sample:
    image = Image.open(img_path).convert("RGB")
    boxes, scores, labels = detect(image)
    masks   = segment(image, boxes)
    overlay = draw_overlay(image, masks, labels, scores)

    fig, axes = plt.subplots(1, 2, figsize=(16, 7))
    fig.suptitle(f"{img_path.name}  |  {len(boxes)} detections", fontsize=11)
    axes[0].imshow(image);   axes[0].set_title("Original"); axes[0].axis("off")
    axes[1].imshow(overlay); axes[1].set_title("Detections + Masks"); axes[1].axis("off")

    patches = [mpatches.Patch(color=np.array(v)/255., label=k) for k, v in CLASS_COLORS.items()]
    fig.legend(handles=patches, loc="lower center", ncol=3, fontsize=9)
    plt.tight_layout()
    plt.show()

    for label, score in zip(labels, scores):
        print(f"  {label}: {score:.3f}")
    print()
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/models/grounding_dino/processing_grounding_dino.py:91: FutureWarning: The key `labels` is will return integer ids in `GroundingDinoProcessor.post_process_grounded_object_detection` output since v4.51.0. Use `text_labels` instead to retrieve string object names.
#   warnings.warn(self.message, FutureWarning)
#   window: 0.374
#   window: 0.304
#   window: 0.376
#   window: 0.393
#   window: 0.379
#   window: 0.381
#   window: 0.374
#   window: 0.359
#   window: 0.363
#   window: 0.369
#   window: 0.361
#   window: 0.382
#   window: 0.347
#   window: 0.364
#   window: 0.402
#   window: 0.372
#   window: 0.363
#   window: 0.343
#   window: 0.377
#   window: 0.389
#   window: 0.362
#   window: 0.383
#   window: 0.352
#   window: 0.376
#   window: 0.359
#   window: 0.352
#   window: 0.356
#   window: 0.361
#   window: 0.353
#   window: 0.336
#   window: 0.325
#   window: 0.349
#   window: 0.342
#   window: 0.365
#   window: 0.355
#   window: 0.352
#   window: 0.336
#   window: 0.350
#   window: 0.350
#   window: 0.337
#   window: 0.341
#   window: 0.352
#   window: 0.347
#   window: 0.362
#   window: 0.358
#   window: 0.333
#   window: 0.351
#   window: 0.341
#   window: 0.339
#   window: 0.335
#   window: 0.338
#   window: 0.353
#   window: 0.343
#   window: 0.335
#   window: 0.360
#   window: 0.347
#   window: 0.345
#   window: 0.316
#   window: 0.318
#   window: 0.348
#   window: 0.344
#   window: 0.337
#   window: 0.339
#   window: 0.316
#   window: 0.333
#   window: 0.351
#   window: 0.362
#   window: 0.344
#   window: 0.356
#   window: 0.335
#   window: 0.348
#   window: 0.346
#   window: 0.317
#   window: 0.342
#   window: 0.346
#   window: 0.324
#   window: 0.311
#   window: 0.362
#   window: 0.335
#   window: 0.338
#   window: 0.325
#   window: 0.321
#   window: 0.340
#   window: 0.330
#   window: 0.323
#   window: 0.330
#   window: 0.330
#   window: 0.328
#   window: 0.327
#   window: 0.316
#   window: 0.340
#   window: 0.339
#   window: 0.332
#   window: 0.350
#   window: 0.321
#   window: 0.339
#   window: 0.342
#   window: 0.350
#   window: 0.320
#   window: 0.351
#   window: 0.341
#   window: 0.351
#   window: 0.341
#   window: 0.331
#   window: 0.333
#   window: 0.327
#   window: 0.358
#   window: 0.326
#   window: 0.331
#   window: 0.304
#   window: 0.303
#   window: 0.344
#   window: 0.347
#   window: 0.356
#   window: 0.319
#   window: 0.322
#   window: 0.311
#   window: 0.318
#   window: 0.342
#   window: 0.323
#   window: 0.327
#   window: 0.347
#   window: 0.321
#   window: 0.326
#   window: 0.306
#   window: 0.316
#   window: 0.339
#   window: 0.340
#   window: 0.353
#   window: 0.338
#   window: 0.343
#   window: 0.308
#   window: 0.356
#   window: 0.338
#   window: 0.322
#   window: 0.322
#   window: 0.305
#   window: 0.327
#   window: 0.309
#   window: 0.319
#   window: 0.319
#   window: 0.305
#   window: 0.327
#   window: 0.310
#   window: 0.311
#   window: 0.316
#   window: 0.306
#   window: 0.302
#   window: 0.312
#   window: 0.319
#   window: 0.305
#   window: 0.321
#   window: 0.301
#   window: 0.310
#   window: 0.340
#   window: 0.330
#   window: 0.327
#   window: 0.304
#   window: 0.314
#   window: 0.337
#   window: 0.315
#   window: 0.322
#   window: 0.329
#   window: 0.349
#   window: 0.324
#   window: 0.380
#   window: 0.360
#   window: 0.355
#   window: 0.316
#   window: 0.301
#   window: 0.302
#   window: 0.323
#   window: 0.558
#   window: 0.553
#   window: 0.522
#   window: 0.532
#   window: 0.554
#   window: 0.543
#   window: 0.513
#   window: 0.502
#   window: 0.496
#   window: 0.509
#   window: 0.422
#   window: 0.529
#   window: 0.495
#   window: 0.534
#   window: 0.445
#   window: 0.437
#   window: 0.473
#   window: 0.445
#   window: 0.464
#   window: 0.477
#   window: 0.443
#   window: 0.443
#   window: 0.534
#   window: 0.350
#   window: 0.363
#   balcony: 0.411
#   window: 0.432
#   window: 0.467
#   window: 0.416
#   window: 0.405
#   balcony: 0.412
#   window: 0.440
#   window: 0.307
#   window: 0.454
#   window: 0.417
#   balcony: 0.303
#   window: 0.340
#   window: 0.471
#   window: 0.441
#   balcony: 0.329
#   window: 0.348
#   balcony: 0.313
#   window: 0.365
#   door: 0.352
#   door: 0.398
#   door: 0.309
#   door: 0.301
#   balcony: 0.321
#   balcony: 0.389
#   window: 0.336
#   window: 0.350
#   window: 0.337
#   window: 0.353
#   window: 0.383
#   window: 0.328
#   window: 0.380
#   window: 0.347
#   window: 0.327
#   window: 0.348
#   window: 0.323
#   window: 0.375
#   window: 0.375
#   window: 0.360
#   window: 0.343
#   window: 0.327
#   window: 0.346
#   window: 0.329
#   window: 0.336
#   window: 0.326
#   window: 0.319
#   window: 0.324
#   window: 0.317
#   window: 0.312
#   window: 0.343
#   window: 0.335
#   window: 0.317
#   window: 0.330
#   window: 0.375
#   window: 0.351
#   window: 0.326
#   window: 0.352
#   window: 0.315
#   window: 0.336
#   window: 0.324
#   window: 0.328
#   window: 0.320
#   window: 0.360
#   window: 0.333
#   window: 0.316
#   window: 0.307
#   window: 0.326
#   window: 0.374
#   window: 0.364
#   window: 0.320
#   window: 0.309
#   window: 0.338
#   window: 0.323
#   window: 0.304
#   window: 0.315
#   window: 0.346
#   window: 0.331
#   window: 0.366
#   window: 0.321
#   window: 0.347
#   window: 0.332
#   window: 0.311
#   window: 0.341
#   window: 0.316
#   window: 0.320
#   window: 0.351
#   window: 0.304
#   window: 0.318
#   window: 0.308
#   window: 0.314
#   window: 0.308
#   window: 0.317
#   window: 0.316
#   window: 0.360
#   window: 0.318
#   window: 0.347
#   window: 0.312
#   window: 0.331
#   window: 0.322
#   window: 0.317
#   window: 0.331
#   window: 0.341
#   window: 0.339
#   window: 0.307
#   window: 0.308
#   window: 0.302
#   window: 0.340
#   window: 0.357
#   window: 0.307
#   window: 0.317
#   window: 0.326
#   window: 0.301
#   window: 0.319
#   window: 0.309
#   window: 0.329
#   window: 0.311
#   window: 0.308
#   window: 0.307
#   window: 0.306
#   window: 0.303
#   window: 0.307
#   window: 0.301
#   window: 0.300
#   window: 0.322
#   window: 0.342
#   window: 0.335
#   window: 0.303
#   window: 0.318
#   window: 0.330
#   window: 0.325
#   window: 0.310
#   window: 0.318
#   window: 0.300
#   window: 0.325
#   window: 0.313
#   window: 0.314
#   window: 0.320
#   window: 0.324
#   window: 0.333
#   window: 0.355
#   window: 0.333
#   window: 0.350
#   window: 0.352
#   window: 0.325
#   window: 0.327
#   window: 0.329
#   window: 0.338
#   window: 0.328
#   window: 0.316
#   window: 0.348
#   window: 0.315
#   window: 0.325
#   window: 0.313
#   window: 0.312
#   window: 0.305
#   window: 0.303
#   window: 0.312
#   window: 0.316
#   window: 0.304
#   window: 0.329
#   window: 0.301
#   window: 0.330
#   window: 0.313
#   window: 0.308
#   window: 0.301
#   window: 0.300
#   window: 0.320
#   window: 0.327
#   window: 0.329
#   window: 0.312
#   window: 0.312
#   window: 0.321

# %%
# Full dataset inference
overlay_dir = Path(OUTPUT_DIR) / "overlays"
mask_dir    = Path(OUTPUT_DIR) / "masks"
overlay_dir.mkdir(parents=True, exist_ok=True)
mask_dir.mkdir(parents=True, exist_ok=True)

coco_images, coco_annotations, ann_id = [], [], 1

for img_id, img_path in enumerate(tqdm(paths, desc="Inference"), start=1):
    try:
        image = Image.open(img_path).convert("RGB")
        W, H  = image.size
        boxes, scores, labels = detect(image)
        masks = segment(image, boxes)

        draw_overlay(image, masks, labels, scores).save(
            overlay_dir / f"{img_path.stem}_overlay.png")

        for i, (mask, label, score) in enumerate(zip(masks, labels, scores)):
            Image.fromarray(mask.astype(np.uint8) * 255, mode="L").save(
                mask_dir / f"{img_path.stem}_{i:03d}_{label}.png")

        coco_images.append({"id": img_id, "file_name": img_path.name, "width": W, "height": H})
        for mask, label, score in zip(masks, labels, scores):
            ys, xs = np.where(mask)
            if len(xs) == 0:
                continue
            x0, y0, x1, y1 = int(xs.min()), int(ys.min()), int(xs.max()), int(ys.max())
            coco_annotations.append({
                "id": ann_id, "image_id": img_id,
                "category_name": label,
                "bbox":   [x0, y0, x1 - x0, y1 - y0],
                "score":  float(score),
                "segmentation": mask_to_rle(mask),
                "area":   int(mask.sum()),
                "iscrowd": 0,
            })
            ann_id += 1

        torch.cuda.empty_cache()

    except Exception as e:
        print(f"ERROR {img_path.name}: {e}")
        torch.cuda.empty_cache()

coco_out = {
    "images": coco_images,
    "annotations": coco_annotations,
    "categories": [{"id": i+1, "name": k} for i, k in enumerate(CLASS_COLORS)],
}
(Path(OUTPUT_DIR) / "results.json").write_text(json.dumps(coco_out, indent=2))

print(f"\nDone. {len(paths)} images | {ann_id-1} instances")
print(f"  overlays/    — RGB с масками и боксами")
print(f"  masks/       — бинарные маски per instance")
print(f"  results.json — COCO JSON для импорта в CVAT")
# Out:
# Inference:   0%|          | 0/697 [00:00<?, ?it/s]/tmp/ipykernel_22515/2172767151.py:20: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   Image.fromarray(mask.astype(np.uint8) * 255, mode="L").save(
# Inference:   2%|▏         | 16/697 [09:04<6:26:09, 34.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22515/2172767151.py in <cell line: 0>()
#      32                 "bbox":   [x0, y0, x1 - x0, y1 - y0],
#      33                 "score":  float(score),
# ---> 34                 "segmentation": mask_to_rle(mask),
#      35                 "area":   int(mask.sum()),
#      36                 "iscrowd": 0,
#
# /tmp/ipykernel_22515/4162989304.py in mask_to_rle(mask)
#     107     for v in flat:
#     108         if v == prev:
# --> 109             run += 1
#     110         else:
#     111             counts.append(run); run = 1; prev = v
#
# KeyboardInterrupt:
